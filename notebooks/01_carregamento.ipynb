# %%
import pandas as pd

# Carregando o CSV enviado pelo Artur em ml/data/raw/
caminho = '../data/raw/iranian_churn.csv'
df = pd.read_csv(caminho)

# 1. Validação de formato (3.150 linhas, 13 preditores e 1 alvo, totalizando 14 colunas)
print(f"Dimensões do Dataset: {df.shape[0]} linhas x {df.shape[1]} colunas\n")

# 2. Tipos de dados de cada coluna
print("--- Tipos de Dados ---")
print(df.dtypes)

# 3. Primeiras 5 linhas
df.head()
# Out:
# Dimensões do Dataset: 3150 linhas x 14 colunas
#
# --- Tipos de Dados ---
# Call  Failure                int64
# Complains                    int64
# Subscription  Length         int64
# Charge  Amount               int64
# Seconds of Use               int64
# Frequency of use             int64
# Frequency of SMS             int64
# Distinct Called Numbers      int64
# Age Group                    int64
# Tariff Plan                  int64
# Status                       int64
# Age                          int64
# Customer Value             float64
# Churn                        int64
# dtype: object
#    Call  Failure  Complains  Subscription  Length  Charge  Amount  \
# 0              8          0                    38               0
# 1              0          0                    39               0
# 2             10          0                    37               0
# 3             10          0                    38               0
# ...
